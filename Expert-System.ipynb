# %%
# Knowledge Base
restaurants = [
    {
        'name': 'Yumpies',
        'cuisine': 'Fast Food',
        'Veg/Non_Veg':'Non Veg',
        'price_range': 'Medium',
        'location': 'Mess 1',
        'rating': 4.5,
        'style_of_service': 'Takeaway',
        'Method_of_Payment':'UPI'
    },
    {
        'name': 'ANC 1',
        'cuisine': 'Fast Food',
        'Veg/Non_Veg':'Non Veg',
        'price_range':'Cheap',
        'location': 'Mess 1',
        'rating': 3.2,
        'style_of_service': 'Dining',
        'Method_of_Payment':'Smartcampus'
    },
    {
        'name': 'Thickshake',
        'cuisine': 'Beverages',
        'Veg/Non_Veg':'Veg',
        'price_range': 'Expensive',
        'location': 'Mess 1',
        'rating': 3.8,
        'style_of_service': 'Takeaway',
        'Method_of_Payment':'UPI'
    },
    {
        'name': 'Chipotle',
        'cuisine': 'South Indian',
        'Veg/Non_Veg':'Veg',
        'price_range': 'Cheap',
        'location': 'Mess 1',
        'rating': 2.8,
        'style_of_service': 'Dining',
        'Method_of_Payment':'UPI'
    },
    {
        'name': 'SFC',
        'cuisine': 'Fast Food',
        'Veg/Non_Veg':'Non Veg',
        'price_range': 'Medium',
        'location': 'Mess 2',
        'rating': 3.9,
        'style_of_service': 'Takeaway',
        'Method_of_Payment':'UPI'
    },
    {
        'name': 'Wich Please',
        'cuisine': 'Fast Food',
        'Veg/Non_Veg':'Veg',
        'price_range': 'Cheap',
        'location': 'Mess 2',
        'rating': 3.5,
        'style_of_service': 'Takeaway',
        'Method_of_Payment':'UPI'
    },
    {
        'name': 'Mess 2 Shawarama',
        'cuisine': 'Fast Food',
        'price_range': 'Medium',
        'location': 'Mess 2',
        'rating': 3.3,
        'style_of_service': 'Takeaway',
        'Method_of_Payment':'Smartcampus'
    },
    {
        'name': 'ANC 2',
        'cuisine': 'Fast Food',
        'price_range': 'Cheap',
        'location': 'Mess 2',
        'rating': 3.3,
        'style_of_service': 'Takeaway',
        'Method_of_Payment':'Smartcampus'
    },
    {
        'name': 'Hotspot',
        'cuisine': 'Fast Food',
        'price_range': 'Expensive',
        'location': 'SAC',
        'rating': 4.2,
        'style_of_service': 'Takeaway',
        'Method_of_Payment':'UPI'
    },
    {
        'name': 'Vijay Vahini',
        'cuisine': 'North Indian',
        'price_range': 'Medium',
        'location': 'SAC',
        'rating': 4.0,
        'style_of_service': 'Dining',
        'Method_of_Payment':'UPI'
    },
    {
        'name': 'Fruitful',
        'cuisine': 'Medium',
        'price_range': 'Medium',
        'location': 'SAC',
        'rating': 3.9,
        'style_of_service': 'Takeaway',
        'Method_of_Payment':'UPI'
    },
    {
        'name': 'Tea-Time',
        'cuisine': 'Medium',
        'price_range': 'Medium',
        'location': 'SAC',
        'rating': 4.5,
        'style_of_service': 'Takeaway',
        'Method_of_Payment':'UPI'
    },
    {
        'name': 'Pleasant',
        'cuisine': 'Expensive',
        'price_range': 'Expensive',
        'location': 'SAC',
        'rating': 4.3,
        'style_of_service': 'Dining',
        'Method_of_Payment':'UPI'
    },
    {
        'name': 'Agra Chaat',
        'cuisine': 'North Indian',
        'price_range': 'Cheap',
        'location': 'SAC',
        'rating': 4.3,
        'style_of_service': 'Dining',
        'Method_of_Payment':'UPI'
    }
    
]

# User Interface
print("Welcome to the Restaurant Recommendation System!")
print("Please answer the following questions to get a recommendation.")

cuisine_preference = input("What cuisine do you prefer?(Fast Food/North Indian/South Indian/Beverages) ")
price_range_preference = input("What price range are you looking for?(Cheap/Medium/Expensive) ")
location_preference = input("Where would you like the restaurant to be located?(Mess 1/Mess 2/SAC) ")
style_of_service_preference = input("What kind of service do you want? (Dining/Takeaway)")
method_of_payment_prefernce = input("How do you wish to pay (UPI/Smartcampus)")

# Inference Engine
matched_restaurants = []

for restaurant in restaurants:
    if restaurant['cuisine'].lower() == cuisine_preference.lower() and \
       restaurant['price_range'].lower() == price_range_preference.lower() and \
       restaurant['location'].lower() == location_preference.lower() and \
       restaurant['price_range'].lower() == price_range_preference.lower() and \
       restaurant['style_of_service'].lower() == style_of_service_preference.lower() and \
       restaurant['Method_of_Payment'].lower() == method_of_payment_preference.lower():
        matched_restaurants.append(restaurant)

# Rule Base
if len(matched_restaurants) > 0:
    print("Based on your preferences, I recommend the following restaurants:")
    for restaurant in matched_restaurants:
        print(f"- {restaurant['name']} ({restaurant['cuisine']}) - Rating: {restaurant['rating']}")
else:
    print("Sorry, there are no restaurants matching your preferences.")
# Out:
# Welcome to the Restaurant Recommendation System!
# Please answer the following questions to get a recommendation.
# What cuisine do you prefer?(Fast Food/North Indian/South Indian/Beverages) Fast Food
# What price range are you looking for?(Cheap/Medium/Expensive) Cheap
# Where would you like the restaurant to be located?(Mess 1/Mess 2/SAC) Mess 1
# What kind of service do you want? (Dining/Takeaway)Dining
# How do you wish to pay (UPI/Smartcampus)UPI
# Sorry, there are no restaurants matching your preferences.
